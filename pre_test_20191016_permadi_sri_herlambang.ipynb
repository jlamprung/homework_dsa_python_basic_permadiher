# %%
import pandas as ps
df_churn = ps.read_csv("churn.csv", encoding='latin1')

# %%
df_churn.shape
# Out:
# (5000, 21)

# %%
df_churn.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'phone_number',
#        'international_plan', 'voice_mail_plan', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'class'],
#       dtype='object')

# %%
df_churn.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %% [markdown]
# ***1. Check berapa rata rata total call untuk day, eve, dan night dari seluruh populasi, dan tentukan quartile-nya, untuk pelanggan yang status jumlah call-nya kurang dari Q1, dikategorikan sebagai pelanggan yang memiliki kemungkinan churn***
# <br>
# <br>

# %%
df_churn[['total_day_calls','total_eve_calls','total_night_calls']].describe()
# Out:
#        total_day_calls  total_eve_calls  total_night_calls
# count      5000.000000      5000.000000        5000.000000
# mean        100.029400       100.191000          99.919200
# std          19.831197        19.826496          19.958686
# min           0.000000         0.000000           0.000000
# 25%          87.000000        87.000000          87.000000
# 50%         100.000000       100.000000         100.000000
# 75%         113.000000       114.000000         113.000000
# max         165.000000       170.000000         175.000000

# %%
df_churn[df_churn.total_day_calls < 87]
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 3        35              84        408          2510                   1
# 7        24             147        415           116                   1
# 9        49             141        415           163                   1
# 14       12              62        415          2065                   0
# 15       34             161        415          1268                   0
# ...     ...             ...        ...           ...                 ...
# 4977     11              53        510          1544                   1
# 4978     16             108        408          3227                   0
# 4984     42              74        510           716                   0
# 4992     26              83        415          1476                   0
# 4998      7             109        510          3471                   0
#
#       voice_mail_plan  number_vmail_messages  total_day_minutes  \
# ...

# %%
df_churn[df_churn.total_eve_calls < 87]
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 8        18             117        408           425                   0
# 10       15              65        415           100                   0
# 12       12             168        408          1854                   0
# 13       26              95        510          3509                   0
# 14       12              62        415          2065                   0
# ...     ...             ...        ...           ...                 ...
# 4981     27              61        510          4257                   0
# 4983     18             137        408          3793                   0
# 4987      2             127        415          3645                   0
# 4993     49              73        408          4467                   0
# 4996     49             152        415           394                   0
#
#       voice_mail_plan  number_vmail_messages  total_day_minutes  \
# ...

# %%
df_churn[df_churn.total_night_calls < 87]
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 16       13              85        408          1218                   0
# 19       43              73        415          2374                   0
# 21        5              77        408          3452                   0
# 22        3             130        415          1618                   0
# 27       26              54        408          4803                   0
# ...     ...             ...        ...           ...                 ...
# 4978     16             108        408          3227                   0
# 4987      2             127        415          3645                   0
# 4989     23             150        408          4217                   0
# 4991      3              97        510          4367                   0
# 4992     26              83        415          1476                   0
#
#       voice_mail_plan  number_vmail_messages  total_day_minutes  \
# ...

# %% [markdown]
# ***2. Check summary statistik berdasarkan total jumlah voice mail message***

# %%
df_churn['number_vmail_messages'].describe()
# Out:
# count    5000.000000
# mean        7.755200
# std        13.546393
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        17.000000
# max        52.000000
# Name: number_vmail_messages, dtype: float64

# %%
df_churn[df_churn.number_vmail_messages > 17]
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 0        16             128        415          2845                   0
# 1        35             107        415          2301                   0
# 6        19             121        510          1516                   0
# 9        49             141        415           163                   1
# 16       13              85        408          1218                   0
# ...     ...             ...        ...           ...                 ...
# 4971     11             128        510          4339                   0
# 4985     27             118        510           897                   0
# 4987      2             127        415          3645                   0
# 4995     11              50        408          2000                   0
# 4999     46              86        415          2412                   0
#
#       voice_mail_plan  number_vmail_messages  total_day_minutes  \
# ...

# %% [markdown]
# ***3.  Check Summary statistik berdasarkan number_customer_service_calls***

# %%
df_churn['number_customer_service_calls'].describe()
# Out:
# count    5000.000000
# mean        1.570400
# std         1.306363
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         9.000000
# Name: number_customer_service_calls, dtype: float64

# %%
df_churn[df_churn.number_customer_service_calls > 2]
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 4        36              75        415           155                   1
# 6        19             121        510          1516                   0
# 10       15              65        415           100                   0
# 13       26              95        510          3509                   0
# 14       12              62        415          2065                   0
# ...     ...             ...        ...           ...                 ...
# 4982     43              86        408          1759                   0
# 4985     27             118        510           897                   0
# 4986     35             125        415          1917                   0
# 4993     49              73        408          4467                   0
# 4996     49             152        415           394                   0
#
#       voice_mail_plan  number_vmail_messages  total_day_minutes  \
# ...

# %% [markdown]
# ***4.  Tentukan korelasi, antara variabel total call day eve night, dengan voice mail dan jumlah call ke customer service, mana yang memiliki korelasi yang lebih kuat***

# %%
df_churn[['number_customer_service_calls','number_vmail_messages','total_day_calls','total_eve_calls','total_night_calls']].corr(method="pearson")
# Out:
#                                number_customer_service_calls  \
# number_customer_service_calls                       1.000000
# number_vmail_messages                              -0.007086
# total_day_calls                                    -0.010739
# total_eve_calls                                     0.006235
# total_night_calls                                  -0.008283
#
#                                number_vmail_messages  total_day_calls  \
# number_customer_service_calls              -0.007086        -0.010739
# number_vmail_messages                       1.000000         0.000883
# total_day_calls                             0.000883         1.000000
# total_eve_calls                            -0.003954         0.003754
# total_night_calls                           0.002676        -0.008308
#
#                                total_eve_calls  total_night_calls
# number_customer_service_calls         0.006235          -0.008283
# ...

# %% [markdown]
# ***5. Tentukan summary statistik dari tiga variable voice mail number, total day calls dan total night calls***

# %%
df_churn[['number_vmail_messages','total_day_calls','total_night_calls']].describe()
# Out:
#        number_vmail_messages  total_day_calls  total_night_calls
# count            5000.000000      5000.000000        5000.000000
# mean                7.755200       100.029400          99.919200
# std                13.546393        19.831197          19.958686
# min                 0.000000         0.000000           0.000000
# 25%                 0.000000        87.000000          87.000000
# 50%                 0.000000       100.000000         100.000000
# 75%                17.000000       113.000000         113.000000
# max                52.000000       165.000000         175.000000

# %%
df_churn[(df_churn.number_vmail_messages > 17) & (df_churn.total_day_calls < 87) & (df_churn.total_night_calls < 87)  ]
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 35       10              72        415          1814                   0
# 41       20             135        408          2906                   1
# 265      49             114        510          4763                   0
# 278       1             131        415          1799                   0
# 294      48              96        510           827                   0
# ...     ...             ...        ...           ...                 ...
# 4362     12              52        510          2726                   0
# 4385     31             134        415          4426                   0
# 4416     39              76        510          2693                   0
# 4594     48              41        408          4686                   1
# 4779      8              74        415          3114                   0
#
#       voice_mail_plan  number_vmail_messages  total_day_minutes  \
# ...
