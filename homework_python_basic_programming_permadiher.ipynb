# %%
import pandas as pd
import numpy as np
data_google_playstore = pd.read_csv("googleplaystore.csv", encoding='latin1')

# %%
data_google_playstore.shape
# Out:
# (10841, 13)

# %% [markdown]
# * * *
# ***Question 1***
#
# In your Jupyter Notebook or Google Colab, import numpy and pandas library, then perform loading dataset that you have got and stored in a folder named dataset. Typical code for loading dataset is as follows:
#
# google_play_apps = pd.read_csv('dataset/googleplaystore.csv')
#
# In the dataset of googleplaystore.csv, it consists of  blank rows and  blank columns.

# %% [markdown]
# ***The Answer of Question no 1***
# <br>
# 10841 rows and 13 columns
#
# ***Solution***
# <br>
# data_google_playstore.shape
# * * *

# %% [markdown]
# * * *
# ***Question 2***
# <br>
# How many unique apps categories reflected in the dataset?
# <br>
# <br>
# ***The Answer of Question no 2***
# <br>
# 34 Apps Categories
#
# ***Solution***
# <br>
# data_google_playstore.groupby('Category').nunique().shape
# * * *

# %%
data_google_playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_google_playstore.groupby('Category')['App'].nunique().shape
# Out:
# (34,)

# %%
data_google_playstore[data_google_playstore.Category=='1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data_google_playstore.groupby('Category').nunique()
# Out:
#                       App  Category  Rating  Reviews  Size  Installs  Type  \
# Category
# 1.9                     1         1       1        1     1         1     1
# ART_AND_DESIGN         64         1      14       64    48        12     2
# AUTO_AND_VEHICLES      85         1      18       72    57        15     2
# BEAUTY                 53         1      14       48    37        12     1
# BOOKS_AND_REFERENCE   222         1      20      168   105        17     2
# BUSINESS              420         1      31      205   139        18     2
# COMICS                 56         1      19       60    41        11     1
# COMMUNICATION         316         1      25      290   118        19     2
# DATING                171         1      27      153    81        15     2
# EDUCATION             119         1      13      130    57         9     2
# ENTERTAINMENT         102         1      16      110    42        10     2
# ...

# %%
data_google_playstore.groupby('Category').nunique().shape
# Out:
# (34, 13)

# %% [markdown]
# * * *
# ***Question 3***
# <br>
# How many unique genres according to the dataset?
# <br>
# <br>
# ***The Answer of Question no 3***
# <br>
# 120 Unique Apps Genres
#
# ***Solution***
# <br>
# data_google_playstore.groupby('Genres').nunique().shape
# * * *

# %%
data_google_playstore.groupby('Genres').nunique().shape
# Out:
# (120, 13)

# %%
data_google_playstore.groupby('Genres').nunique()
# Out:
#                                        App  Category  Rating  Reviews  Size  \
# Genres
# Action                                 299         1      18      347   100
# Action;Action & Adventure               12         2       7       15    11
# Adventure                               73         1      14       75    53
# Adventure;Action & Adventure             5         2       3       12     5
# Adventure;Brain Games                    1         1       1        1     1
# ...                                    ...       ...     ...      ...   ...
# Video Players & Editors                163         1      26      159    84
# Video Players & Editors;Creativity       1         2       1        2     1
# Video Players & Editors;Music & Video    2         2       1        3     2
# Weather                                 79         1      15       79    45
# Word                                    23         1      11       28    21
#
# ...

# %% [markdown]
# * * *
# ***Question 4***
# <br>
# Which code is appropriate to drop duplicate values in 'App' column and remove its rows in Python?  Assume dataset was loaded as a pandas data frame variable: google_play_apps.
# <br>
# <br>
# ***The Answer of Question no 4***
# <br>
# google_play_apps.drop_duplicates(subset='App', inplace=False)
#
# ***Solution***
# <br>
# google_play_apps.drop_duplicates(subset='App', inplace=False)
# * * *

# %%
data_google_playstore.groupby(['App']).size().reset_index(name='counts').sort_values(by=['counts'], ascending=False)
# Out:
#                                                     App  counts
# 7302                                             ROBLOX       9
# 1934  CBS Sports App - Scores, News, Stats & Watch Live       8
# 2364                                   Candy Crush Saga       7
# 3504                     Duolingo: Learn Languages Free       7
# 101                                         8 Ball Pool       7
# ...                                                 ...     ...
# 3310                         Display Phone Screen On TV       1
# 3311                                  Displaying You VR       1
# 3312                             Ditto CP Calculator GO       1
# 3313                                      Dive-Store.ch       1
# 9659  ð¥ Football Wallpapers 4K | Full HD Backgrou...       1
#
# [9660 rows x 2 columns]

# %%
data_google_playstore.drop_duplicates(subset='App', inplace=False).groupby(['App']).size().reset_index(name='counts').sort_values(by=['counts'], ascending=False)
# Out:
#                                                     App  counts
# 0                "i DT" FÃºtbol. Todos Somos TÃ©cnicos.       1
# 6434                                     My Talking Tom       1
# 6436                        My Teacher - Classroom Play       1
# 6437                                          My Telcel       1
# 6438                                           My Tele2       1
# ...                                                 ...     ...
# 3220  Delivery trough - delivery trough delivery trough       1
# 3221                                     Delivery yogi.       1
# 3222                                       Delta Dental       1
# 3223                             Denis Brogniart - AH !       1
# 9659  ð¥ Football Wallpapers 4K | Full HD Backgrou...       1
#
# [9660 rows x 2 columns]

# %%
data_google_playstore.drop_duplicates(subset='App', inplace=False)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_google_playstore[data_google_playstore.App=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up

# %%
data_google_playstore.groupby(['App']).size().reset_index(name='counts').sort_values(by=['counts'], ascending=False)
# Out:
#                                                     App  counts
# 0                "i DT" FÃºtbol. Todos Somos TÃ©cnicos.       1
# 6434                                     My Talking Tom       1
# 6436                        My Teacher - Classroom Play       1
# 6437                                          My Telcel       1
# 6438                                           My Tele2       1
# ...                                                 ...     ...
# 3220  Delivery trough - delivery trough delivery trough       1
# 3221                                     Delivery yogi.       1
# 3222                                       Delta Dental       1
# 3223                             Denis Brogniart - AH !       1
# 9659  ð¥ Football Wallpapers 4K | Full HD Backgrou...       1
#
# [9660 rows x 2 columns]

# %% [markdown]
# * * *
# ***Question 5***
# <br>
# Upon removing duplicate of App column, please run the following code to remove a row that contain 'Free' value at the 'Installs' column. You can check first with this code:
#
# google_play_apps[google_play_apps['Installs']=='Free']
# To remove that specific row:
#
# google_play_apps = google_play_apps[google_play_apps['Installs'] != 'Free']
# If you want to remove character '+' in column 'Installs', you can run the following codes in Python.
#
# google_play_apps['Installs'] = google_play_apps blank .apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
# Then, if you want to remove character ',' in column 'Installs', you can run the following codes in Python.
#
# google_play_apps['Installs'] =  blank ['Installs'].apply(lambda x: x.replace( blank , '') if ',' in str(x) else x)
# Assume that you loaded dataset as a pandas data frame with variable name: google_play_apps.
#
# To understand lambda, please read this article.
# <br>
# <br>
# ***The Answer of Question no 5***
# <br>
# google_play_apps['Installs'] = google_play_apps['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
#
# google_play_apps['Installs'] = google_play_apps['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
#
# ***Solution***
# <br>
# google_play_apps['Installs'] = google_play_apps['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
#
# google_play_apps['Installs'] = google_play_apps['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
# * * *

# %%
data_google_playstore.groupby('Installs').size()
# Out:
# Installs
# 0                    1
# 0+                  14
# 1+                  67
# 1,000+             888
# 1,000,000+        1417
# 1,000,000,000+      20
# 10+                385
# 10,000+           1031
# 10,000,000+        937
# 100+               710
# 100,000+          1112
# 100,000,000+       188
# 5+                  82
# 5,000+             468
# 5,000,000+         607
# 50+                204
# 50,000+            469
# 50,000,000+        202
# 500+               328
# 500,000+           505
# 500,000,000+        24
# Free                 1
# dtype: int64

# %%
data_google_playstore[data_google_playstore.Installs == 'Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data_google_playstore = data_google_playstore[data_google_playstore.Installs != 'Free']

# %%
data_google_playstore[data_google_playstore.Installs == 'Free']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
data_google_playstore.groupby('Installs').size()
# Out:
# Installs
# 0                    1
# 0+                  14
# 1+                  67
# 1,000+             888
# 1,000,000+        1417
# 1,000,000,000+      20
# 10+                385
# 10,000+           1031
# 10,000,000+        937
# 100+               710
# 100,000+          1112
# 100,000,000+       188
# 5+                  82
# 5,000+             468
# 5,000,000+         607
# 50+                204
# 50,000+            469
# 50,000,000+        202
# 500+               328
# 500,000+           505
# 500,000,000+        24
# dtype: int64

# %%
data_google_playstore['Installs'].head()
# Out:
# 0        10,000+
# 1       500,000+
# 2     5,000,000+
# 3    50,000,000+
# 4       100,000+
# Name: Installs, dtype: object

# %%
data_google_playstore['Installs'] = data_google_playstore['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
# Out:
# c:\users\permadiher\appdata\local\continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_google_playstore.groupby('Installs').size()
# Out:
# Installs
# 0                  15
# 1                  67
# 1,000             888
# 1,000,000        1417
# 1,000,000,000      20
# 10                385
# 10,000           1031
# 10,000,000        937
# 100               710
# 100,000          1112
# 100,000,000       188
# 5                  82
# 5,000             468
# 5,000,000         607
# 50                204
# 50,000            469
# 50,000,000        202
# 500               328
# 500,000           505
# 500,000,000        24
# dtype: int64

# %%
data_google_playstore['Installs'] = data_google_playstore['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
# Out:
# c:\users\permadiher\appdata\local\continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_google_playstore['Installs'].head()
# Out:
# 0       10000
# 1      500000
# 2     5000000
# 3    50000000
# 4      100000
# Name: Installs, dtype: object

# %% [markdown]
# * * *
# ***Question 6***
# <br>
# If you want to convert data type of 'Installs' columns into integer, you can run the following code.
#
# google_play_apps blank = google_play_apps blank .astype( blank )
# Assume you loaded dataset as a pandas data frame with variable name: google_play_apps.
# <br>
# <br>
# ***The Answer of Question no 6***
# data_google_playstore['Installs'] = data_google_playstore['Installs'].astype(int)
#
# ***Solution***
# <br>
# data_google_playstore['Installs'] = data_google_playstore['Installs'].astype(int)
# * * *

# %%
data_google_playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data_google_playstore['Installs'] = data_google_playstore['Installs'].astype(int)
# Out:
# c:\users\permadiher\appdata\local\continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_google_playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data_google_playstore[(data_google_playstore.App == 'DU Battery Saver - Battery Charger & Battery Life') 
                      | (data_google_playstore.App == 'Flipboard: News For Our Time')
                      | (data_google_playstore.App == 'Pinterest')
                      | (data_google_playstore.App == 'Dropbox')
                      | (data_google_playstore.App == 'Subway Surfers')
                      | (data_google_playstore.App == 'WhatsApp Messenger')
                      | (data_google_playstore.App == 'File Commander - File Manager/Explorer')
                    | (data_google_playstore.App == 'FIFA Soccer')
                     ]
# Out:
#                                                      App            Category  \
# 336                                   WhatsApp Messenger       COMMUNICATION
# 1654                                      Subway Surfers                GAME
# 2552                                           Pinterest              SOCIAL
# 3473                                             Dropbox        PRODUCTIVITY
# 3755                        Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 8445                                         FIFA Soccer              SPORTS
# 8896   DU Battery Saver - Battery Charger & Battery Life               TOOLS
# 10253             File Commander - File Manager/Explorer            BUSINESS
#
#        Rating   Reviews                Size    Installs  Type Price  \
# 336       4.4  69119316  Varies with device  1000000000  Free     0
# 1654      4.5  27722264                 76M  1000000000  Free     0
# 2552      4.6   4305441  Varies with device   100000000  Free     0
# ...

# %% [markdown]
# * * *
# ***Question 7***
# <br>
# Match Apps and Category based on provided dataset!
#
# (Hint: Use App and Category columns)
#
# DU Battery Saver - Battery Charger & Battery Life
#
# Answer 1
# Flipboard: News For Our Time	Answer 2
# Pinterest
#
# Answer 3
# Dropbox
#
# Answer 4
# Subway Surfers
#
# Answer 5
# WhatsApp Messenger
#
# Answer 6
# File Commander - File Manager/Explorer
#
# Answer 7
# FIFA Soccer
# <br>
# <br>
# ***The Answer of Question no 7***
#
#
#
# DU Battery Saver - Battery Charger & Battery Life ***TOOLS***
# <br>
# Flipboard: News For Our Time	***NEWS_AND_MAGAZINES***
# <br>
# Pinterest ***SOCIAL***
# <br>
# Dropbox ***PRODUCTIVITY***
# <br>
# Subway Surfers ***GAME***
# <br>
# WhatsApp Messenger ***COMMUNICATION***
# <br>
# File Commander - File Manager/Explorer ***BUSINESS***
# <br>
# FIFA Soccer ***SPORT***
# <br>
#
#
# ***Solution***
# <br>
# data_google_playstore[(data_google_playstore.App == 'DU Battery Saver - Battery Charger & Battery Life')
#                       | (data_google_playstore.App == 'Flipboard: News For Our Time')
#                       | (data_google_playstore.App == 'Pinterest')
#                       | (data_google_playstore.App == 'Dropbox')
#                       | (data_google_playstore.App == 'Subway Surfers')
#                       | (data_google_playstore.App == 'WhatsApp Messenger')
#                       | (data_google_playstore.App == 'File Commander - File Manager/Explorer')
#                     | (data_google_playstore.App == 'FIFA Soccer')
#                      ]
# * * *

# %% [markdown]
# * * *
# ***Question 8***
# <br>
# The following applications were installed by more than 1 billion users, EXCEPT ... .
#
# Select one:
# a. Facebook
# b. WhatsApp Messenger
# c. Google Duo - High Quality Video Calls
# d. Skype
#
# ***The Answer of Question no 8***
# <br>
# Google Duo - High Quality Video Calls
# <br>
#
# ***Solution***
# <br>
# data_google_playstore[data_google_playstore.Installs >= 1000000000]
#
# * * *

# %%
data_google_playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_google_playstore[data_google_playstore.Installs >= 1000000000]
# Out:
#                                              App             Category  Rating  \
# 152                            Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335   Messenger â Text and Video Chat for Free        COMMUNICATION     4.0
# 336                           WhatsApp Messenger        COMMUNICATION     4.4
# 338                 Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                        Gmail        COMMUNICATION     4.3
# 341                                     Hangouts        COMMUNICATION     4.0
# 391                Skype - free IM & video calls        COMMUNICATION     4.1
# 865                            Google Play Games        ENTERTAINMENT     4.3
# 1654                              Subway Surfers                 GAME     4.5
# 2544                                    Facebook               SOCIAL     4.1
# 2545                                   Instagram               SOCIAL     4.5
# ...

# %%
data_google_playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data_google_playstore['Reviews'] = data_google_playstore['Reviews'].astype(int)
# Out:
# c:\users\permadiher\appdata\local\continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_google_playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data_google_playstore[data_google_playstore.Category=='COMMUNICATION'].sort_values(by=['Reviews'], ascending=False).head(50)
# Out:
#                                                     App       Category  \
# 336                                  WhatsApp Messenger  COMMUNICATION
# 335          Messenger â Text and Video Chat for Free  COMMUNICATION
# 378         UC Browser - Fast Download Private & Secure  COMMUNICATION
# 406                         BBM - Free Calls & Messages  COMMUNICATION
# 342                                     Viber Messenger  COMMUNICATION
# 403                         LINE: Free Calls & Messages  COMMUNICATION
# 391                       Skype - free IM & video calls  COMMUNICATION
# 338                        Google Chrome: Fast & Secure  COMMUNICATION
# 449   Truecaller: Caller ID, SMS spam blocking & Dialer  COMMUNICATION
# 365                                              WeChat  COMMUNICATION
# 351                       Opera Mini - fast web browser  COMMUNICATION
# 347                       imo free video calls and chat  COMMUNICATION
# ...

# %% [markdown]
# * * *
# ***Question 9***
# <br>
# Arrange top COMMUNICATION category apps from the highest number of reviews to the lowest!
#
# (Hint: Convert the data type to integer first. It is similar with code that was asked in question 6.
#
# ***The Answer of Question no 9***
# <br>
# 1. Whats app messenger
# 2. BBM
# 3. Viber Messenger
# 4. Line
# 5. Skype
# <br>
#
# ***Solution***
# <br>
# data_google_playstore['Reviews'] = data_google_playstore['Reviews'].astype(int)
# data_google_playstore[data_google_playstore.Category=='COMMUNICATION'].sort_values(by=['Reviews'], ascending=False).head(50)
#
# * * *

# %%
data_google_playstore['Rating'] = data_google_playstore['Rating'].astype(float)
# Out:
# c:\users\permadiher\appdata\local\continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_google_playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data_google_playstore[data_google_playstore.Category == 'GAME'].sort_values(by=['Installs','Rating'], ascending=False)
# Out:
#                      App Category  Rating   Reviews                Size  \
# 1654      Subway Surfers     GAME     4.5  27722264                 76M
# 1722      My Talking Tom     GAME     4.5  14891223  Varies with device
# 1655    Candy Crush Saga     GAME     4.4  22426677                 74M
# 1661        Temple Run 2     GAME     4.3   8118609                 62M
# 1662                 Pou     GAME     4.3  10485308                 24M
# ...                  ...      ...     ...       ...                 ...
# 5917            Ra Ga Ba     GAME     5.0         2                 20M
# 10697            Mu.F.O.     GAME     5.0         2                 16M
# 4218   D+H Reaction Wall     GAME     NaN         0  Varies with device
# 5846           YAKALA AY     GAME     NaN         0                 14M
# 6277    Bi-Tank Ads Free     GAME     NaN         0  Varies with device
#
#          Installs  Type  Price Content Rating  Genres      Last Updated  \
# ...

# %% [markdown]
# * * *
# ***Question 10***
# <br>
# Arrange top 3 game category apps based on number of installed and rating!
#
# ***The Answer of Question no 10***
# <br>
# 1. Subway Surfers
# 2. My Talking Tom
# 3. Candy Crush Saga
# <br>
#
# ***Solution***
# <br>
# data_google_playstore['Rating'] = data_google_playstore['Rating'].astype(float)
# data_google_playstore[data_google_playstore.Category == 'GAME'].sort_values(by=['Installs','Rating'], ascending=False)
#
# * * *
